# %%
import pandas as pd
from sqlalchemy import create_engine

# 1️⃣ Load the CSV
df = pd.read_csv(r"C:\Users\rafeh\python_jupyter_stuff\data_analytics_project_materials\superstore.csv")

# 2️⃣ Connect to PostgreSQL
engine = create_engine("postgresql://postgres:password@localhost:5432/superstore_project")

# 3️⃣ Upload the data into PostgreSQL
df.to_sql("superstore_sales", engine, if_exists="replace", index=False)

print("Upload completed successfully!")
# Out:
# Upload completed successfully!

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\rafeh\\anac\\python.exe'
